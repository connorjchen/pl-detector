# %%
# !pip install scikit-learn

# %%
# Clean scraped data set

import pandas as pd

df_initial = pd.read_csv("training_data/data_set.csv")

tokens=['#', ';', ',', '.', '/', '(', ')', '==', '=', '+', '-', '*',
        '&', '|', '}', '{', ']', '[', '!', '<', '>', '<=', '>=', '!=',
        '||', '&&', '()', '"', "'", '?', '^', '%']

words=['boolean', 'double', 'if', 'return', "while", 'break', 'else', 'int',
      'static', 'char', 'false', 'new', 'true', 'class', 'for', 'public',
      'void', 'abstract', 'byvalue', 'case', 'cast', 'catch', 'const', 'continue',
      'extends', 'do', 'default', 'finalize', 'final', 'import', 'inner', 'instanceof',
      'interface', 'long', 'native', 'null', 'operator', 'outer', 'package',
      'private', 'protected', 'rest', 'short', 'super', 'switch', 'synchronized',
      'this', 'throw', 'throws', 'transient', 'try', 'var', 'volatile', 'auto', 'enum',
      'extern', 'float', 'goto', 'inline', 'register', 'restrict', 'unsigned', 'signed',
       'sizeof', 'struct', 'typedef', 'union', 'dynamic_cast', 'explicit', 'friend', 'namespace', 
       'typeid', 'typename', 'and', 'as', 'assert', 'def', 'elif', 'del', 'from', 'global', 'in', 'is', 'lambda', 
       'None', 'not', 'or', 'pass', 'raise', 'yield', 'asr', 'begin', 'fun', 'function', 'functor', 'inherit', 
       'initializer', 'land', 'match', 'let', 'module', 'mutable', 'rec', 'nonrec', 'of', 'sig', 'then', 'virtual', 
       'print', 'cout', 'cin', 'printf', 'scanf', 'input', 'print_endline', 'System.out.println', 'System.out.print']

languages = []
token0 = []
token1 = []
token2 = []
token3 = []
token4 = []
token5 = []
token6 = []
token7 = []
token8 = []
token9 = []
token10 = []
token11 = []
token12 = []
token13 = []
token14 = []
token15 = []
token16 = []
token17 = []
token18 = []
token19 = []
token20 = []
token21 = []
token22 = []
token23 = []
token24 = []
token25 = []
token26 = []
token27 = []
token28 = []
token29 = []
token30 = []
token31 = []
word0 = []
word1 = []
word2 = []
word3 = []
word4 = []
word5 = []
word6 = []
word7 = []
word8 = []
word9 = []
word10 = []
word11 = []
word12 = []
word13 = []
word14 = []
word15 = []
word16 = []
word17 = []
word18 = []
word19 = []
word20 = []
word21 = []
word22 = []
word23 = []
word24 = []
word25 = []
word26 = []
word27 = []
word28 = []
word29 = []
word30 = []
word31 = []
word32 = []
word33 = []
word34 = []
word35 = []
word36 = []
word37 = []
word38 = []
word39 = []
word40 = []
word41 = []
word42 = []
word43 = []
word44 = []
word45 = []
word46 = []
word47 = []
word48 = []
word49 = []
word50 = []
word51 = []
word52 = []
word53 = []
word54 = []
word55 = []
word56 = []
word57 = []
word58 = []
word59 = []
word60 = []
word61 = []
word62 = []
word63 = []
word64 = []
word65 = []
word66 = []
word67 = []
word68 = []
word69 = []
word70 = []
word71 = []
word72 = []
word73 = []
word74 = []
word75 = []
word76 = []
word77 = []
word78 = []
word79 = []
word80 = []
word81 = []
word82 = []
word83 = []
word84 = []
word85 = []
word86 = []
word87 = []
word88 = []
word89 = []
word90 = []
word91 = []
word92 = []
word93 = []
word94 = []
word95 = []
word96 = []
word97 = []
word98 = []
word99 = []
word100 = []
word101 = []
word102 = []
word103 = []
word104 = []
word105 = []
word106 = []
word107 = []
word108 = []
word109 = []
word110 = []
word111 = []
word112 = []
word113 = []
word114 = []
word115 = []
word116 = []

# count subtractions (nested doubles accounted for in ., int, sig, print):
# contents.count('=') - 2*contents.count('==') - contents.count('<=') - contents.count('>=') - contents.count('!=')
# contents.count('|') - 2*contents.count('||')
# contents.count('&') - 2*contents.count('&&')
# contents.count('<') - contents.count('<=')
# contents.count('>')  - contents.count('>=')
# contents.count('!') - contents.count('!=')
# contents.count('(') - contents.count('()')
# contents.count(')') - contents.count('()')
# contents.count('.') - contents.count('System.out.print')

# contents.count('final') - contents.count('finalize')
# contents.count('signed') - contents.count('unsigned')
# contents.count('if') - contents.count('elif')
# contents.count('int') - contents.count('interface') - contents.count('print') 
# contents.count('cast') - contents.count('dynamic_cast')
# contents.count('rest') - contents.count('restrict')
# contents.count('throw') - contents.count('throws')
# contents.count('or') - contents.count('for') - contents.count('import') - contents.count('operator') - contents.count('short') - contents.count('functor')
# contents.count('fun') - contents.count('function') - contents.count('functor') 
# contents.count('rec') - contents.count('nonrec')
# contents.count('of') - contents.count('sizeof') - contents.count('instanceof')
# contents.count('sig') - contents.count('signed')
# contents.count('print') - contents.count('printf') - contents.count('print_endline') - contents.count('System.out.print')
# contents.count('System.out.println') - contents.count('System.out.print')

for i, row in df_initial.iterrows():
    contents = row['contents']
    if (type(contents) != type('example string')):
        continue
    token0.append(contents.count('#'))
    token1.append(contents.count(';'))
    token2.append(contents.count(','))
    token3.append(contents.count('.') - contents.count('System.out.print'))
    token4.append(contents.count('/'))
    token5.append(contents.count('(') - contents.count('()'))
    token6.append(contents.count(')') - contents.count('()'))
    token7.append(contents.count('=='))
    token8.append(contents.count('=') - 2*contents.count('==') - contents.count('<=') - contents.count('>=') - contents.count('!='))
    token9.append(contents.count('+'))
    token10.append(contents.count('-'))
    token11.append(contents.count('*'))
    token12.append(contents.count('&') - 2*contents.count('&&'))
    token13.append(contents.count('|') - 2*contents.count('||'))
    token14.append(contents.count('}'))
    token15.append(contents.count('{'))
    token16.append(contents.count(']'))
    token17.append(contents.count('['))
    token18.append(contents.count('!') - contents.count('!='))
    token19.append(contents.count('<') - contents.count('<='))
    token20.append(contents.count('>')  - contents.count('>='))
    token21.append(contents.count('<='))
    token22.append(contents.count('>='))
    token23.append(contents.count('!='))
    token24.append(contents.count('||'))
    token25.append(contents.count('&&'))
    token26.append(contents.count('()'))
    token27.append(contents.count('"'))
    token28.append(contents.count('\''))
    token29.append(contents.count('?'))
    token30.append(contents.count('^'))
    token31.append(contents.count('%'))
    word0.append(contents.count('boolean'))
    word1.append(contents.count('double'))
    word2.append(contents.count('if') - contents.count('elif'))
    word3.append(contents.count('return'))
    word4.append(contents.count('while'))
    word5.append(contents.count('break'))
    word6.append(contents.count('else'))
    word7.append(contents.count('int') - contents.count('interface') - contents.count('print'))
    word8.append(contents.count('static'))
    word9.append(contents.count('char'))
    word10.append(contents.count('false'))
    word11.append(contents.count('new'))
    word12.append(contents.count('true'))
    word13.append(contents.count('class'))
    word14.append(contents.count('for'))
    word15.append(contents.count('public'))
    word16.append(contents.count('void'))
    word17.append(contents.count('abstract'))
    word18.append(contents.count('byvalue'))
    word19.append(contents.count('case'))
    word20.append(contents.count('cast') - contents.count('dynamic_cast'))
    word21.append(contents.count('catch'))
    word22.append(contents.count('const'))
    word23.append(contents.count('continue'))
    word24.append(contents.count('extends'))
    word25.append(contents.count('do'))
    word26.append(contents.count('default'))
    word27.append(contents.count('finalize'))
    word28.append(contents.count('final') - contents.count('finalize'))
    word29.append(contents.count('import'))
    word30.append(contents.count('inner'))
    word31.append(contents.count('instanceof'))
    word32.append(contents.count('interface'))
    word33.append(contents.count('long'))
    word34.append(contents.count('native'))
    word35.append(contents.count('null'))
    word36.append(contents.count('operator'))
    word37.append(contents.count('outer'))
    word38.append(contents.count('package'))
    word39.append(contents.count('private'))
    word40.append(contents.count('protected'))
    word41.append(contents.count('rest') - contents.count('restrict'))
    word42.append(contents.count('short'))
    word43.append(contents.count('super'))
    word44.append(contents.count('switch'))
    word45.append(contents.count('synchronized'))
    word46.append(contents.count('this'))
    word47.append(contents.count('throw') - contents.count('throws'))
    word48.append(contents.count('throws'))
    word49.append(contents.count('transient'))
    word50.append(contents.count('try'))
    word51.append(contents.count('var'))
    word52.append(contents.count('volatile'))
    word53.append(contents.count('auto'))
    word54.append(contents.count('enum'))
    word55.append(contents.count('extern'))
    word56.append(contents.count('float'))
    word57.append(contents.count('goto'))
    word58.append(contents.count('inline'))
    word59.append(contents.count('register'))
    word60.append(contents.count('restrict'))
    word61.append(contents.count('unsigned'))
    word62.append(contents.count('signed') - contents.count('unsigned'))
    word63.append(contents.count('sizeof'))
    word64.append(contents.count('struct'))
    word65.append(contents.count('typedef'))
    word66.append(contents.count('union'))
    word67.append(contents.count('dynamic_cast'))
    word68.append(contents.count('explicit'))
    word69.append(contents.count('friend'))
    word70.append(contents.count('namespace'))
    word71.append(contents.count('typeid'))
    word72.append(contents.count('typename'))
    word73.append(contents.count('and'))
    word74.append(contents.count('as'))
    word75.append(contents.count('assert'))
    word76.append(contents.count('def'))
    word77.append(contents.count('elif'))
    word78.append(contents.count('del'))
    word79.append(contents.count('from'))
    word80.append(contents.count('global'))
    word81.append(contents.count('in'))
    word82.append(contents.count('is'))
    word83.append(contents.count('lambda'))
    word84.append(contents.count('None'))
    word85.append(contents.count('not'))
    word86.append(contents.count('or') - contents.count('for') - contents.count('import') - contents.count('operator') - contents.count('short') - contents.count('functor'))
    word87.append(contents.count('pass'))
    word88.append(contents.count('raise'))
    word89.append(contents.count('yield'))
    word90.append(contents.count('asr'))
    word91.append(contents.count('begin'))
    word92.append(contents.count('fun') - contents.count('function') - contents.count('functor'))
    word93.append(contents.count('function'))
    word94.append(contents.count('functor'))
    word95.append(contents.count('inherit'))
    word96.append(contents.count('initializer'))
    word97.append(contents.count('land'))
    word98.append(contents.count('match'))
    word99.append(contents.count('let'))
    word100.append(contents.count('module'))
    word101.append(contents.count('mutable'))
    word102.append(contents.count('rec') - contents.count('nonrec'))
    word103.append(contents.count('nonrec'))
    word104.append(contents.count('of') - contents.count('sizeof') - contents.count('instanceof'))
    word105.append(contents.count('sig') - contents.count('signed'))
    word106.append(contents.count('then'))
    word107.append(contents.count('virtual'))
    word108.append(contents.count('print') - contents.count('printf') - contents.count('print_endline') - contents.count('System.out.print'))
    word109.append(contents.count('cout'))
    word110.append(contents.count('cin'))
    word111.append(contents.count('printf'))
    word112.append(contents.count('scanf'))
    word113.append(contents.count('input'))
    word114.append(contents.count('print_endline'))
    word115.append(contents.count('System.out.println'))
    word116.append(contents.count('System.out.println') - contents.count('System.out.print'))
    languages.append(row['language'])
    
dict_for_df = {'language' : languages, '#': token0, ';': token1, ',': token2, 
                            '.': token3, '/': token4, '(': token5, 
                            ')': token6, '==': token7, '=': token8, 
                            '+': token9, '-': token10, '*': token11, 
                            '&': token12, '|': token13, '}': token14, 
                            '{': token15, ']': token16, '[': token17, 
                            '!': token18, '<': token19, '>': token20, 
                            '<=': token21, '>=': token22, '!=': token23, 
                            '||': token24, '&&': token25, '()': token26, 
                            '"': token27, "'": token28, '?': token29, 
                            '^': token30, '%': token31, 
                            'boolean': word0, 'double': word1, 
                            'if': word2, 'return': word3, 'while': word4, 
                            'break': word5, 'else': word6, 'int': word7, 
                            'static': word8, 'char': word9, 'false': word10,
                            'new': word11, 'true': word12, 'class': word13, 
                            'for': word14, 'public': word15, 'void': word16, 
                            'abstract': word17, 'byvalue': word18, 'case': word19, 
                            'cast': word20, 'catch': word21, 'const': word22, 
                            'continue': word23, 'extends': word24, 'do': word25, 
                            'default': word26, 'finalize': word27, 'final': word28, 
                            'import': word29, 'inner': word30, 'instanceof': word31, 
                            'interface': word32, 'long': word33, 'native': word34, 
                            'null': word35, 'operator': word36, 'outer': word37, 
                            'package': word38, 'private': word39, 'protected': word40, 
                            'rest': word41, 'short': word42, 'super': word43, 
                            'switch': word44, 'synchronized': word45, 'this': word46, 
                            'throw': word47, 'throws': word48, 'transient': word49, 
                            'try': word50, 'var': word51, 'volatile': word52, 
                            'auto': word53, 'enum': word54, 'extern': word55, 
                            'float': word56, 'goto': word57, 'inline': word58, 
                            'register': word59, 'restrict': word60, 'unsigned': word61,
                            'signed': word62, 'sizeof': word63, 'struct': word64, 
                            'typedef': word65, 'union': word66, 'dynamic_cast': word67,
                            'explicit': word68, 'friend': word69, 'namespace': word70, 
                            'typeid': word71, 'typename': word72, 'and': word73, 
                            'as': word74, 'assert': word75, 'def': word76, 'elif': word7,
                            'del': word78, 'from': word79, 'global': word80, 'in': word81, 
                            'is': word82, 'lambda': word83, 'None': word84, 'not': word85, 
                            'or': word86, 'pass': word87, 'raise': word88, 'yield': word89,
                            'asr': word90, 'begin': word91, 'fun': word92, 
                            'function': word93, 'functor': word94, 'inherit': word95, 
                            'initializer': word96, 'land': word97, 'match': word98, 
                            'let': word99, 'module': word100, 'mutable': word101, 
                            'rec': word102, 'nonrec': word103, 
                            'of': word104, 'sig': word105, 'then': word106,
                            'virtual': word107, 'print': word108, 
                            'cout': word109, 'cin': word110, 
                            'printf': word111, 'scanf': word112,
                            'input': word113, 'print_endline': word114,
                            'System.out.println': word115, 
                            'System.out.print': word116}
df_final = pd.DataFrame(dict_for_df)
def normalize(row):
    # print(row[1:], "TEST")
    total_tokens = len(row) - 1
    total_sum = 0
    print(row[0])
    for i in row[1:]:
        # print(i)
        total_sum += int(i) ** 2
    
    total_sum = total_sum ** 0.5
        
    for i, item in enumerate(row[1:]):  
        # print(i, item)
        
        row[i + 1] = item / total_sum
    # print(row)
    return row

# df_final.iloc[:,:] = Normalizer(norm='l1').fit_transform(df_final)
df_final = df_final.apply(lambda row: normalize(row), axis=1)
df_final.to_csv("cleaned_data_set.csv", index=None)
df_final
# Out:
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ocaml
# ...

# %%
# Implement ML model

# TODO: add hyperparameters to model? choose different models? implement neural net for fun? live prediction webpage for demo? compare to guesslang?

import sklearn as sk
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn import tree
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.cluster import KMeans
# from sklearn.datasets import load_iris, load_breast_cancer

df_final = pd.read_csv("cleaned_data_set.csv")
matrix_final = df_final.to_numpy()

x = matrix_final[:,1:]
y = matrix_final[:,0]

y[y == 'java'] = 0
y[y == 'python'] = 1
y[y == 'ocaml'] = 2
y[y == 'c'] = 3
y[y == 'c++'] = 4

y=y.astype('int')

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)


logreg_model = LogisticRegression(max_iter=1200000)
nb_model = GaussianNB()

logreg_model.fit(x_train, y_train)
nb_model.fit(x_train, y_train)

print('Logistic Regression Prediction: ', logreg_model.predict(x_test))
print('Naive Bayes Prediction: ', nb_model.predict(x_test))
print('Actual Values: ', y_test)
print("Logistic Regression testing error: %2.1f%%" % (100 *(logreg_model.predict(x_test) != y_test).mean()))
print("Naive Bayes testing error: %2.1f%%" % (100 *(nb_model.predict(x_test) != y_test).mean()))

# Attempt at printing probability of prediction for each class - idk if it works, it has strong opinions
# print(100 * nb_model.predict_proba(x_test))
# for y_pred in 100 * nb_model.predict_proba(x_test):
#     for class_prob in y_pred:
#         print("Naive Bayes testing error: %2.5f%%" % (class_prob))
# Out:
# Logistic Regression Prediction:  [3 4 2 1 0 3 4 4 4 3 3 3 1 0 2 4 4 1 1 2 0 1 2 0 4 0 2 2 3 4 1 4 3 1 2 0 0
#  4 0 4 0 0 1 0 0 4 2 2 4 0 3 3 4 4 3 1 2 4 2 4 3 0 4 4 3 1 0 4 3 3 1 4 0 0
#  4 1 3 4 1 2 4 3 4 1 3 2 4 0 4 4 4 1 4 3 4 3 4 4 4 4 0 0 4 3 4 1 0 1 2 2 1
#  2 1 3 4 0 3 1 3 4 4 4 3 4 4 3 4 1 2 0 1 4 4 4 3 4 1 4 1 2 1 2 1 2 3 1 4 2
#  0 0 4 4 4 3 3 2 1 0 4 1 3 1 3 3 0 4 1 4 2 2 2 4 0 4]
# Naive Bayes Prediction:  [3 3 2 1 0 4 3 4 4 3 4 3 1 0 2 4 3 1 1 2 0 1 0 0 3 0 0 2 3 4 1 4 4 1 2 0 0
#  3 0 3 2 0 1 0 0 3 2 2 4 0 4 3 3 3 3 1 2 3 2 3 4 0 3 3 3 1 0 3 3 3 1 4 0 0
#  4 3 3 3 1 2 4 3 3 1 4 2 4 0 4 4 3 0 3 3 3 3 3 3 3 4 0 0 4 0 3 1 0 1 2 2 1
#  2 1 3 4 0 3 1 3 4 4 3 3 3 4 3 4 1 2 2 1 3 4 4 3 3 1 4 1 2 1 2 4 2 4 1 3 2
#  0 0 3 4 3 3 3 2 1 0 3 1 3 1 3 4 0 4 1 3 1 2 2 4 0 3]
# Actual Values:  [4 3 2 1 0 3 4 3 3 4 4 3 1 0 2 4 3 1 1 2 0 1 2 0 3 0 2 2 4 4 1 3 3 1 2 0 0
#  3 0 4 0 0 1 0 0 4 2 2 3 0 3 4 3 3 4 1 2 4 2 3 3 0 3 3 4 1 0 3 4 3 1 3 0 0
# ...

# %%
# Save the files
from joblib import dump, load

dump(logreg_model, "logreg_model.joblib")
dump(nb_model, "nb_model.joblib")
# Out:
# ['nb_model.joblib']
